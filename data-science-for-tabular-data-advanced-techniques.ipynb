# %% [markdown]
# <a class="anchor" id="0"></a>
#
# # This is a collection of the best Kaggle notebooks (kernels) and other resources (including notebooks (kernels) and posts in discussion from *Prize Competition Winners*) with Advanced Techniques of Data Science for tabular data

# %% [markdown]
# ## Sources:
# ### - Notebooks (kernels) or posts of the Prize Competition Winners
# ### - Notebooks (kernels) of Kaggle Grandmasters, Masters or Experts
# ### - Detailed tutorials of the leading Python libraries
# etc.

# %% [markdown]
# # New Updates:
# * **Fixed links to sections 8.4 and 8.5 in the table of contents (thank you very much [@desplanl](https://www.kaggle.com/desplanl) for your comment about that)**
# * **Add the post ["Techniques to improve your leaderboard position"](https://www.kaggle.com/c/tabular-playground-series-jan-2021/discussion/213090) from Grandmaster [@gpreda](https://www.kaggle.com/gpreda) to chapter "9. DS Tutorial"**
# * **Added notebook from the winner (4th place - Gold Prize Place) of the competition [Mechanisms of Action (MoA) Prediction](https://www.kaggle.com/c/lish-moa)**
# * **Add interesting notebooks with many useful tips and tricks into sections 8.1 Sklearn, 8.2. Numpy and 8.3 Pandas**

# %% [markdown]
# <a class="anchor" id="0.1"></a>
# ## Table of Contents
# [Acknowledgement notebook (kernel) and post authors](#0.2)
# 1. [Prize Competition Winners: Kernels and Posts with Magic](#1)
#     -  [IEEE-CIS Fraud Detection](#1.1)
#     -  [Santander Customer Transaction Prediction](#1.2)
#     -  [Instant Gratification](#1.3)
#     -  [Predicting Molecular Properties](#1.4)
#     -  [VSB Power Line Fault Detection](#1.5)
#     -  [Elo Merchant Category Recommendation](#1.6)
#     -  [Google Analytics Customer Revenue Prediction](#1.7)
#     -  [NFL Big Data Bowl](#1.8)
#     -  [2019 Data Science Bowl](#1.9)
#     -  [Google Cloud & NCAA® ML Competitions](#1.10)
#        -  [Google Cloud & NCAA® ML Competition 2019-Men's](#1.10.1)
#        -  [Google Cloud & NCAA® ML Competition 2019-Women's](#1.10.2)
#        -  [Google Cloud & NCAA® ML Competition 2018-Men's](#1.10.3)
#        -  [Google Cloud & NCAA® ML Competition 2018-Women's](#1.10.4)
#     -  [Mechanisms of Action (MoA) Prediction](#1.11)
# 1. [Exploratore Data Analyze (EDA)](#2)
# 1. [Feature engineering (FE)](#3)
#     -  [Feature importance](#3.1)
#     -  [Automatic features generation](#3.2)
#         -  [Featuretools](#3.2.1)
#         -  [Autofeat](#3.2.2)
#         -  [GPlearn](#3.2.3)
#     -  [Automatic features selection](#3.3)
#     -  [ELI5, LIME and SHAP](#3.4)
# 1. [Model hyperparameter optimization](#4)
#     -  [GridSearchCV](#4.1)
#     -  [Hyperopt](#4.2)
#     -  [Optuna](#4.3)
# 1. [Models selection](#5)
#     -  [Classifiers](#5.1)
#     -  [Interactive Classifier](#5.2)
#     -  [Regressors](#5.3)
#     -  [Classifiers & Regressors](#5.4)
#     -  [Deep Learning](#5.5)
#     -  [User metric for models](#5.6)
# 1. [Time series analysis and prediction](#6)
#     -  [Statsmodels, ARIMA](#6.1)
#     -  [SARIMAX - Seasonal ARIMA](#6.2)
#     -  [Test stationarity and transform the dataset to stationary](#6.3)
#     -  [Time series with Facebook Prophet](#6.4)
# 1. [Probability prediction with calibration](#7)
# 1. [Universal toolkits](#8)
#     -  [Sklearn](#8.1)
#     -  [NumPy](#8.2)
#     -  [Pandas](#8.3)
#     -  [AutoML](#8.4)
#     -  [PyCaret](#8.5)
# 1. [DS Tutorials](#9)

# %% [markdown]
# ## Acknowledgment to notebook and post authors <a class="anchor" id="0.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ### Thanks to notebook (kernel) authors (including Kaggle Prize Competition Winners):
#
# * @ashishpatel26,
# * @augustmarvel,
# * @berhag,
# * @bigswimatom,
# * @braquino,
# * @cdeotte,
# * @dbrait,
# * @dollofcuty,
# * @duythedewey,
# * @freespirit08,
# * @frtgnn,
# * @gdub279,
# * @jackyourdata,
# * @jaredcross,
# * @jazivxt,
# * @jesucristo,
# * @jleecook,
# * @kanncaa1,
# * @kashnitsky,
# * @kento1993,
# * @kostoglot,
# * @kushal1506,
# * @kyakovlev,
# * @lachhebo,
# * @liananapalkova,
# * @mtodisco10,
# * @n1sarg,
# * @nroman,
# * @ogrellier,
# * @oguzkoroglu,
# * @osspringfall,
# * @prashant111,
# * @python10pm,
# * @raddar,
# * @steubk,
# * @suicaokhoailang,
# * @superluminal098,
# * @sz8416,
# * @tarobxl,
# * @tentotheminus9,
# * @thebrownviking20,
# * @toshik,
# * @vbmokin,
# * @vikumsw,
# * @vipulgandhi,
# * @yufengg
#
# ### for their wonderful and helpful notebooks (kernels)!

# %% [markdown]
# ### Thanks to post authors (Kaggle Prize Competition Winners):
#
# * @a763337092,
# * @azacharia,
# * @bolkonsky,
# * @dott1718,
# * @duythedewey,
# * @gamechanger,
# * @gpreda,
# * @jaredcross,
# * @jleecook,
# * @johnpateha,
# * @kangzhang,
# * @khyeh0719,
# * @kingychiu,
# * @leey634,
# * @lish-moa,
# * @marcuslin,
# * @maxjeblick,
# * @nabilblk,
# * @panosc,
# * @raddar,
# * @salmatfq,
# * @sc0d3r,
# * @senkin13,
# * @philippsinger,
# * @pocketsuteado,
# * @wimwim,
# * @xiaozhouwang
#
# ### **for their interesting and helpful posts and work results which used in my notebook (kernel)!**

# %% [markdown]
# ## 1. Prize Competition Winners: Notebooks and Posts with Magic <a class="anchor" id="1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 1.1. [IEEE-CIS Fraud Detection](https://www.kaggle.com/c/ieee-fraud-detection/)<a class="anchor" id="1.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [XGB Fraud with Magic - [0.9600]](https://www.kaggle.com/cdeotte/xgb-fraud-with-magic-0-9600) - 1st place (Private LB), 2st place (Public LB) from 6381**
#
# **Thanks to @cdeotte, @kyakovlev**
#
# Original grouped features, feature selection, encoding features, validation approaches, model selection etc.
#
# General principles in posts of @cdeotte:
# * https://www.kaggle.com/c/ieee-fraud-detection/discussion/111308
# * https://www.kaggle.com/c/ieee-fraud-detection/discussion/111284

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.2. [Santander Customer Transaction Prediction](https://www.kaggle.com/c/santander-customer-transaction-prediction)<a class="anchor" id="1.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 - [Pseudo Labeling - QDA - [0.969]](https://www.kaggle.com/cdeotte/pseudo-labeling-qda-0-969)**
#
# **This kernel uses advanced technique form the kernel [I'm overfitting and I know it](https://www.kaggle.com/nroman/i-m-overfitting-and-i-know-it/notebook)**
#
# **Thanks to @nroman, @cdeotte**
#
# The team **Wizardry** used pseudo labeling to increase their private LB by 0.0005 allowing them to beat 1st place from 8802 teams (Public&Private LB)!
#
#
# ### Use of test data prediction together with training data to model improvement: "I'm overfitting and I know it"
#
# **Pseudo labeling** is the process of adding confident predicted test data to your training data. Pseudo labeling is a 5 step process.
#
# * Build a model using training data
# * Predict labels for an unseen test dataset
# * Add confident predicted test observations to our training data
# * Build a new model using combined data
# * Use your new model to predict the test data and submit to Kaggle
#
# Here is a pictorial explanation using sythetic 2D data.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 2 - [200 Magical Models - Santander - [0.920]](https://www.kaggle.com/cdeotte/200-magical-models-santander-0-920)**
#
# **Thanks to @cdeotte**
#
# Author took 50st place (Silver Medal - Top 1%) from 8802 teams (46st in Public & 50st in Private LB)!
#
# ### Consideration of dependence of probability of target values from a feature values
#
# When LGBM "looks" at the histogram for Var_XX, it "sees" that when var_XX < Threshold the probability of having target=1 is high. And when var_XX > Threshold the probability is low. This can be displayed by showing the predictions made by LGBM (when building a model from only the variable var_XX). LGBM basically predicts target=A1 for var_XX < Threshold and target=A2 otherwise.
#
# LGBM "divides" the histogram with vertical lines because LGBM does not see horizontal differences. A histogram places multiple values into a single bin and produces a smooth picture. If you place every value in its own bin, you will have a jagged picture, where bars change heights from value to value. Some values are unique, some values occur dozens of times.
#
# These counts are the "magic" feature. For each variable, we make a new feature (column) whose value is the number of counts of the corresponding variable. An example of this new column is displayed above next to the histogram. When LGBM has this new feature, it can now "divide" the histogram with horizontal lines in addition to vertical.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.3. [Instant Gratification](https://www.kaggle.com/c/instant-gratification)<a class="anchor" id="1.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel - [3 Clusters Per Class - [0.975]](https://www.kaggle.com/cdeotte/3-clusters-per-class-0-975)**
#
# **Thanks to @cdeotte**
#
# Author took 7st place (Gold Medal) from 1832 teams (21st in Public & 7st in Private LB)!
#
# ### QDA + Pseudo Labeling + Gaussian Mixture

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.4. [Predicting Molecular Properties](https://www.kaggle.com/c/champs-scalar-coupling)<a class="anchor" id="1.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel - [Single LGBM -2.242 = Top54](https://www.kaggle.com/jesucristo/single-lgbm-2-242-top54)**
#
# **Thanks to @jesucristo, @osspringfall, @dollofcuty**
#
# Authors took 42st place (Silver Medal) from 2749 teams (43st in Public & 42st in Private LB)!
#
# ### 8 LGBModels with Manual finetuning and Bayessian Optimization

# %% [markdown]
# ## 1.5. [VSB Power Line Fault Detection](https://www.kaggle.com/c/vsb-power-line-fault-detection)<a class="anchor" id="1.5"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel - [5-fold LSTM Attention (Stateful Metrics) with exp](https://www.kaggle.com/bigswimatom/5-fold-lstm-attention-stateful-metrics-with-exp)**
#
# This kernel uses kernels
# * [5-fold LSTM Attention (fully commented)](https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694)
# * [5-fold LSTM with threshold tuning [0.580 LB]](https://www.kaggle.com/suicaokhoailang/5-fold-lstm-with-threshold-tuning-0-618-lb)
#
# **Thanks to @bigswimatom, @braquino, @suicaokhoailang**
#
# Author @bigswimatom took 67st place (Silver Medal) from 1451 teams (7st in Public & 67st in Private LB)!
#
# ### Keras, TF, LSTM model, tuning with statefull metric that is calculated over a whole epoch

# %% [markdown]
# ## 1.6. [Elo Merchant Category Recommendation](https://www.kaggle.com/c/elo-merchant-category-recommendation/leaderboard)<a class="anchor" id="1.6"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# Unfortunately, none of the winners have download their kernels, but there are some interesting posts in discussion outlining their main ideas and key fragments of it's kernels or link on used kernels of others authors:

# %% [markdown]
# **The post 1 - [#5 solution](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82314)**
#
# **Thanks to @johnpateha**
#
# Post's author took 5st place (Gold Medal) from 4127 teams
#
# ### Regression models stacking and blending

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The post 2 - [7th Place Solution (Updated Late Submission Finding)](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82055)**
#
# Author used **Magic FE** from the **kernel [unobserved data simulation - exploiting target!](https://www.kaggle.com/raddar/unobserved-data-simulation-exploiting-target)** (author of this kernel is @raddar - 13st place (Gold Medal in this competition too)).
#
# **Thanks to @senkin13, @raddar**
#
# Post's author @senkin13 took 7st place (Gold Medal) from 4127 teams in Private LB (Public LB - 3st place)
#
# ### Advanced preprocessing, FE, models selection and their ensembling
# The author claims that the best LGBmodel was better than the ensembled one.
#
# The **kernel [unobserved data simulation - exploiting target!](https://www.kaggle.com/raddar/unobserved-data-simulation-exploiting-target)** with Magic FE, including combinatorics:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The post 3 - [10th place solution](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82093)**
#
# **Thanks to @bolkonsky**
#
# Post's author took 10st place (Gold Medal) from 4127 teams
#
# ### Advanced preprocessing, FE with adversarial validation, single models tuning and their ensembling

# %% [markdown]
# **The post 4 - [11th place solution](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82127)**
#
# **Thanks to @sc0d3r, @nabilblk, @a763337092, @kangzhang**
#
# Author's team took 11st place (Gold Medal) from 4127 teams
#
# ### Advanced FE, models selection, advanced postprocessing

# %% [markdown]
# **The post 5 - [16th Place Summary](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82166)**
#
# Post's author modified and used the null selection idea (**Magic FE**) from the **kernel [Feature Selection with Null Importances](https://www.kaggle.com/ogrellier/feature-selection-with-null-importances)** of @ogrellier from other competition
#
# **Thanks to @kingychiu, @ogrellier**
#
# Post's author @kingychiu took 16st place (Gold Medal) from 4127 teams
#
# ### Advanced FE, models selection, blending solutions

# %% [markdown]
# **The post 6 - [18th place story (pocket's side)](https://www.kaggle.com/c/elo-merchant-category-recommendation/discussion/82107)**
#
# **Thanks to @pocketsuteado, @xiaozhouwang, @khyeh0719, @marcuslin**
#
# Author's team took 18st place (Gold Medal) from 4127 teams
#
# ### Advanced FE, model selection
# An interesting analysis of what gave effect and what did not

# %% [markdown]
# ## 1.7. [Google Analytics Customer Revenue Prediction](https://www.kaggle.com/c/ga-customer-revenue-prediction/leaderboard)<a class="anchor" id="1.7"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 - [Test_score](https://www.kaggle.com/kostoglot/winning-solution)**
#
# **Thanks to @kostoglot**
#
# Author took **1st** place (Gold Medal) from 3611 teams (68st in Public & 1st in Private LB)!
#
# The kernel has a little explanations
#
# ### R (not Python)
# ### Advanced FE, combined LGBModels

# %% [markdown]
# **The kernel 2 - [base model - v2 user level solution](https://www.kaggle.com/augustmarvel/base-model-v2-user-level-solution)**
#
# This kernel uses the kernel [Updated Bayesian + LGBM_XGB_CAT+ FE + Kfold + CV](https://www.kaggle.com/ashishpatel26/updated-bayesian-lgbm-xgb-cat-fe-kfold-cv)
#
# **Thanks to @augustmarvel, @ashishpatel26**
#
# Author @augustmarvel took 40st place (Silver Medal) from 3611 teams (986st in Public & 40st in Private LB)!
#
# The kernel of @augustmarvel has many explanations
#
# ### Python, Advanced FE, ensemble of boosting models

# %% [markdown]
# The kernel [Updated Bayesian + LGBM_XGB_CAT+ FE + Kfold + CV](https://www.kaggle.com/ashishpatel26/updated-bayesian-lgbm-xgb-cat-fe-kfold-cv) has compare and tuning of boosting models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.8. [NFL Big Data Bowl](https://www.kaggle.com/c/nfl-big-data-bowl-2020)<a class="anchor" id="1.8"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The post 1 - [1st place solution The Zoo](https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/119400)**
#
# **Thanks to @dott1718, @philippsinger**
#
# Author's team took 1st place (Gold Medal) from 2038 teams
#
# ### Advanced FE, Data processing, Augmentation & TTA, model selection, CV analysis etc.
# An interesting analysis of what gave effect and what did not. Below in the comments - the model is given (formalization according to the description from **@azacharia**, a member of the winning team **@dott1718** added some clarifying comments to it)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The post 2 - [3rd place (Public LB) Solution - Transformer](https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/119314)**
#
# **Thanks to @wimwim**
#
# Author took 2st place (Gold Medal) in private LB and 3st place in public LB from 2038 teams
#
# Advanced EDA, FE, model is the Transformer (2 layers encoder + 2 layers decoder) - detail describe with figures.
# The kernel unfortunately is missing.

# %% [markdown]
# **The post 3 - [Public 5th place solution overview](https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/119357)**
#
# **Thanks to @maxjeblick, @ph0921**
#
# Author's team took 3st place (Gold Medal) from 2038 teams
#
# ### Advanced FE, Data preprocessing, model building (three possible Transfomer-type blocks and others) etc.

# %% [markdown]
# ## 1.9. [2019 Data Science Bowl](https://www.kaggle.com/c/data-science-bowl-2019)<a class="anchor" id="1.9"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 - [DSB2019_V77_TR_DT_AUG0.5_3TTA (commit 15)](https://www.kaggle.com/limerobot/dsb2019-v77-tr-dt-aug0-5-3tta?scriptVersionId=27448615)**
#
# **Thanks to @limerobot**. He indicated 13 co-authores, though he was one in the team. Apparently that's how he expressed his gratitude
#
# Authors @limerobot took 3st place (Gold Medal) from 3497 teams!

# %% [markdown]
# **The kernel 2 - [DSB2019 - BS 26 (lgb/auc+xgb)](https://www.kaggle.com/steubk/dsb2019-bs-26-lgb-auc-xgb)**
#
# **Thanks to @steubk**
#
# Authors @steubk took 19st place (Silver Medal) from 3497 teams!

# %% [markdown]
# **The kernel 3 - [Quick and dirty regression (commit 1)](https://www.kaggle.com/tarobxl/quick-and-dirty-regression-semi?scriptVersionId=24081032)**
#
# **Thanks to @tarobxl**
#
# Authors @tarobxl took 32st place (Silver Medal) from 3497 teams!

# %% [markdown]
# **The kernel 4 - [37th_place_solution](https://www.kaggle.com/toshik/37th-place-solution)**
#
# **Thanks to @toshik**
#
# Authors @toshik took 37st place (Silver Medal) from 3497 teams!

# %% [markdown]
# **The kernel 5 - [Convert to Regression with tuning](https://www.kaggle.com/vbmokin/convert-to-regression-with-tuning)**
#
# **It's my kernel**
#
# One of the best kernel (LB = 0.546) - **Gold Medal** in the Kaggle Kernels category (a long time he had the best score among of public kernels).
#
# This kernel consist of the results of manual and automatic tuning of various combinations of 6 regression models:
# * LGB,
# * XGB,
# * NN,
# * CNN
# * XGBRegressor,
# * MLPRegressor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1.10. Google Cloud & NCAA® ML Competitions <a class="anchor" id="1.10"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 1.10.1. [Google Cloud & NCAA® ML Competition 2019-Men's](https://www.kaggle.com/c/mens-machine-learning-competition-2019) <a class="anchor" id="1.10.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 (R) - https://github.com/salmatfq/KaggleMarchMadnessFirstPlace**
#
# See explanation in the post: https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/89150
#
# **Thanks to @salmatfq** He used the model of @raddar (see 10.4).
#
# Author @salmatfq took 1st place (Gold Medal) from 866 teams!

# %% [markdown]
# **The kernel 2 (R) - https://github.com/gjwierz/NCAA_Kaggle_2019**
#
# See explanation in the post: https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/88805
#
# **Thanks to @gdub279**
#
# Author @gdub279 took 2st place (Gold Medal) from 866 teams!

# %% [markdown]
# **The kernel 3 (Python) - https://github.com/YouHoo0521/kaggle-madtown-machine-learning-madness-2019**
#
# See explanation in the post: https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/90254
#
# **Thanks to @leey634 (and his 2 co-authors)**
#
# Author @leey634 took 3st place (Gold Medal) from 866 teams!

# %% [markdown]
# **The kernel 4 (R) - https://storage.googleapis.com/kaggle-forum-message-attachments/519417/12991/Kaggle%20Submission%20Model.zip**
#
# See explanation in the post: https://www.kaggle.com/c/mens-machine-learning-competition-2019/discussion/89942
#
# **Thanks to @gamechanger**
#
# Author @gamechanger took 5st place (Gold Medal) from 866 teams!

# %% [markdown]
# ## 1.10.2. [Google Cloud & NCAA® ML Competition 2019-Women's](https://www.kaggle.com/c/womens-machine-learning-competition-2019) <a class="anchor" id="1.10.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 (R) - [1st Place - Regression to Projected MOV](https://www.kaggle.com/jleecook/1st-place-regression-to-projected-mov/)**
#
# See explanation in the post: https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/88451
#
# **Thanks to @jleecook.** The author thanks @raddar.
#
# Author @jleecook took 1st place (Gold Medal) from 500 teams!

# %% [markdown]
# **The post https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/88402**
#
# The kernel link is currently unavailable.
#
# **Thanks to @panosc**
#
# Author @panosc took 2st place (Gold Medal) from 500 teams!

# %% [markdown]
# **The kernel 2 (Python) - https://github.com/duythedewey/Kaggle_NCAA_Womens_2019**
#
# See explanation in the post: https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/90156
#
# **Thanks to @duythedewey**
#
# Author @duythedewey took 3st place (Gold Medal) from 500 teams!

# %% [markdown]
# **The kernel 3 (R) - https://github.com/jfcross4/kaggle_NCAA/blob/master/stage2_womens.R**
#
# See explanation in the post: https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/88462
#
# **Thanks to @jaredcross**
#
# Author @jaredcross took 4st place (Gold Medal) from 500 teams!

# %% [markdown]
# **The kernel 4 (R) - https://github.com/dbrait/ncaa_womens/blob/master/sub_model.R**
#
# The his post https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/90305 hasn't any explanation.
#
# **Thanks to @dbrait.** The author thanks @raddar.
#
# Author @dbrait took 5st place (Gold Medal) from 500 teams!

# %% [markdown]
# ## 1.10.3. [Google Cloud & NCAA® ML Competition 2018-Men's](https://www.kaggle.com/c/mens-machine-learning-competition-2018) <a class="anchor" id="1.10.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# Surprisingly, none of the winners shared their decision or code. At least I didn't find their. If anyone finds - please write in the comments.
#
# There is only the winner **kernel (1st place) @mtodisco10 [NCAA Men's Bball Champions - Ranking Animation](https://www.kaggle.com/mtodisco10/ncaa-men-s-bball-champions-ranking-animation)**, which allows you to analyze the winning commands based on the toolkit Plotly.

# %% [markdown]
# ## 1.10.4. [Google Cloud & NCAA® ML Competition 2018-Women's](https://www.kaggle.com/c/womens-machine-learning-competition-2018) <a class="anchor" id="1.10.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel (Python) - [paris madness](https://www.kaggle.com/raddar/paris-madness)**
#
# The kernel on Python is based on the kernel on R: https://github.com/fakyras/ncaa_women_2018
#
# See explanation in the posts:
# * [2018 code for 1st place solution (R and python)](https://www.kaggle.com/c/womens-machine-learning-competition-2019/discussion/80689)
# * [#1 solution - lucky error](https://www.kaggle.com/c/womens-machine-learning-competition-2018/discussion/53597)
#
# **Thanks to @raddar**
#
# Author @raddar took 1st place (Gold Medal) from 505 teams!

# %% [markdown]
# ## 1.11. Mechanisms of Action (MoA) Prediction <a class="anchor" id="1.11"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 - [nn-svm-tabnet-xgb with pca cnn stacking without pp](https://www.kaggle.com/kento1993/nn-svm-tabnet-xgb-with-pca-cnn-stacking-without-pp)**
#
# See explanation in the post: https://www.kaggle.com/c/lish-moa/discussion/200808
#
# Authors @kento1993, @lish-moa and others took 4st place (Gold Medal and Prize place) from 4373 teams!

# %% [markdown]
# ## to be continued...

# %% [markdown]
# ## 2. Exploratore Data Analyze (EDA) <a class="anchor" id="2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The Kaggle kernels collection [EDA for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/eda-for-tabular-data-advanced-techniques)**
#
# This is a collection of the best Kaggle kernels and other resources with Advanced Techniques of Exploratory Data Analysis (EDA) for tabular data

# %% [markdown]
# ## 3. Feature engineering (FE) <a class="anchor" id="3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **A good paper with an overview of advanced techniques is here: https://elitedatascience.com/feature-engineering-best-practices**

# %% [markdown]
# ## 3.1. Feature importance <a class="anchor" id="3.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [Merging FE & Prediction - xgb, lgb, logr, linr](https://www.kaggle.com/vbmokin/feature-importance-xgb-lgbm-logreg-linreg)**
#
# ### Building the feature importance diagrams in 6 ways on the example of competition "Titanic: Machine Learning from Disaster":
# * XGB
# * LGBM
# * LogisticRegression (with Eli5)
# * LinearRegression (with Eli5)
# * Mean of all
# * Merdging with different weights
#
# As bonus - the building Confusion matrices of all models and merding of predictions by weights from FI diagrams.
#
# The second example of using the same kernel in another competition: [MM 2020 NCAAM: LGB, XGB, LogReg - Tuning&Merging](https://www.kaggle.com/vbmokin/mm-2020-ncaam-lgb-xgb-logreg-tuning-merging)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3.2. Automatic features generation <a class="anchor" id="3.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ### 3.2.1. Featuretools <a class="anchor" id="3.2.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [Titanic - Featuretools (automatic FE)](https://www.kaggle.com/vbmokin/titanic-featuretools-automatic-fe)**
#
# (This kernel basic on the kernel https://www.kaggle.com/liananapalkova/automated-feature-engineering-for-titanic-dataset)
#
# ### Automatic features generation by the Featuretools library

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### The other example: **the kernel [ASHRAE - Automatic FE&FS](https://www.kaggle.com/vbmokin/ashrae-automatic-fe-fs)**

# %% [markdown]
# ### 3.2.2. Autofeat <a class="anchor" id="3.2.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [Titanic - Autofeat (automatic FE)](https://www.kaggle.com/vbmokin/titanic-autofeat-automatic-fe)**
#
# (This kernel basic on the kernel https://www.kaggle.com/lachhebo/autofeat-feature-engineering/comments#652596)
#
# ### Automatic features generation by the Autofeat library

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.2.3. GPlearn <a class="anchor" id="3.2.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [Gplearn Runtime Management and Regression](https://www.kaggle.com/superluminal098/gplearn-runtime-management-and-regression)**
#
# ### Automatic features generation with GPlearn (genetic programming) and Regression, XGB, LGBM:
# * From GPlearn: SymbolicRegressor
# * Models: Ridge, RidgeCV, GradientBoostingRegressor, XGB, LGBM
# * Visualization

# %% [markdown]
# **The kernel 2 [Andrews Features and GPLearn](https://www.kaggle.com/oguzkoroglu/andrews-features-and-gplearn)**
#
# ### Automatic features generation with GPlearn (genetic programming) with RF:
# * From GPlearn: SymbolicRegressor, SymbolicTransformer
# * Model with RandomForestRegressor
# * Feature selection with RFE, RFECV
# * Visualization

# %% [markdown]
# ## 3.3. Automatic features selection <a class="anchor" id="3.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# About **AutoML** please see in the [chapter 7](https://www.kaggle.com/vbmokin/data-science-for-tabular-data-advanced-techniques#7).

# %% [markdown]
# **The kernel 1 [Titanic - Featuretools (automatic FE)](https://www.kaggle.com/vbmokin/titanic-featuretools-automatic-fe)**
#
# (This kernel basic on the kernel https://www.kaggle.com/sz8416/6-ways-for-feature-selection)
#
# ### Automatic features selection by models and methods:
# * basic on the Pearson correlation
# * the SelectFromModel with LinearSVC
# * the SelectFromModel with Lasso
# * the SelectKBest with Chi-2
# * the Recursive Feature Elimination (RFE) with Logistic Regression
# * the Recursive Feature Elimination (RFE) with Random Forest

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 2 [Heart Disease - Automatic AdvEDA & FE & 20 models](https://www.kaggle.com/vbmokin/heart-disease-automatic-adveda-fe-20-models)**
#
# (This kernel basic on the kernel https://www.kaggle.com/vbmokin/titanic-featuretools-automatic-fe)
#
# ### Automatic features selection by models and methods:
# * by the VarianceThreshold
# * by the Pearson correlation
# * by the SelectFromModel with LinearSVC
# * by the SelectFromModel with Lasso
# * by the SelectKBest with Chi-2
# * by the Recursive Feature Elimination (RFE) with Logistic Regression
# * by the Recursive Feature Elimination (RFE) with Random Forest
#
# A given number of features is selected (in the notebook - 20, but this can be changed), which are most often found in the list of optimal features, selected by different methods.

# %% [markdown]
# ## 3.4. ELI5, LIME and SHAP <a class="anchor" id="3.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [What Causes Heart Disease? Explaining the Model](https://www.kaggle.com/tentotheminus9/what-causes-heart-disease-explaining-the-model)**
#
#
# ### Explaining the Model and Visualization of feature importance with:
# * ELI5
# * SHAP

# %% [markdown]
# SHAP: ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 2 [Explainable AI: ELI5,LIME and SHAP](https://www.kaggle.com/kritidoneria/explainable-ai-eli5-lime-and-shap)**
#
# (This kernel basic on the code https://github.com/klemag/pydata_nyc2018-intro-to-model-interpretability)
#
# ### Visualization of feature importance with:
# * ELI5
# * LIME
# * SHAP

# %% [markdown]
# SHAP: ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 3 [Explaining Random Forest Model With LIME](https://www.kaggle.com/vikumsw/explaining-random-forest-model-with-lime)**
#
# (This kernel basic on the code https://github.com/klemag/pydata_nyc2018-intro-to-model-interpretability)
#
# ### Interprete a Random Forest Model with LIME method
# To make this very easy to grasp I have used infamouse Titanic data set to train the ML model.
# Additionally, after reading this Kernel I hope that you would
# * Get an understanding How to use LIME library for a random forest classifier.
# * Get an understanding on how the model makes predictions using LIME method.
# The intent here is not to build the best possible model but rather the focus is on the aspect of interpretability.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 4 [Feature importance - xgb, lgbm, logreg, linreg](https://www.kaggle.com/vbmokin/feature-importance-xgb-lgbm-logreg-linreg)**
#
# ### Feature importance diagrams in ELI5 for:
# * LogisticRegression
# * LinearRegression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. Model hyperparameter optimization <a class="anchor" id="4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 4.1. GridSearchCV <a class="anchor" id="4.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [Titanic (0.83253) - Comparison 20 popular models](https://www.kaggle.com/vbmokin/titanic-0-83253-comparison-20-popular-models)**
#
# ### Optimizing the hyperparameters of 20 models on the example of competition "Titanic: Machine Learning from Disaster" using different technoques including GridSearchCV for such models:
# * KNN or k-Nearest Neighbors
# * Random Forest
# * VotingClassifier (soft voting)

# %% [markdown]
# **The kernel 2 [Heart Disease - Automatic AdvEDA & FE & 20 models](https://www.kaggle.com/vbmokin/heart-disease-automatic-adveda-fe-20-models)**
#
# ### Modeling is carried out with 20 model-classifier (with tuning and cross-validation) for dataset [Heart Disease UCI](https://www.kaggle.com/ronitf/heart-disease-uci):
#
# * Linear Regression, Logistic Regression
# * Naive Bayes
# * k-Nearest Neighbors algorithm
# * Neural network with Keras
# * Support Vector Machines and Linear SVC
# * Stochastic Gradient Descent, Gradient Boosting Classifier, RidgeCV, Bagging Classifier
# * Decision Tree Classifier, Random Forest Classifier, AdaBoost Classifier, XGB Classifier, LGBM Classifier, ExtraTrees Classifier
# * Gaussian Process Classification
# * MLP Classifier (Deep Learning)
# * Voting Classifier

# %% [markdown]
# ## 4.2. HyperOpt <a class="anchor" id="4.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [Titanic (0.83253) - Comparison 20 popular models](https://www.kaggle.com/vbmokin/titanic-0-83253-comparison-20-popular-models)**
#
# ### Optimizing the hyperparameters of 20 models on the example of competition "Titanic: Machine Learning from Disaster" using different technoques including HyperOpt for such models:
# * XGB Classifier
# * LGBM Classifier
# * GradientBoostingClassifier
# * ExtraTreesClassifier

# %% [markdown]
# ## 4.3. Optuna <a class="anchor" id="4.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [[Moa] Pytorch + Optuna (Hyperparameter Tuning)](https://www.kaggle.com/kushal1506/moa-pytorch-optuna-hyperparameter-tuning)**
#
# ### Optimizing the hyperparameters of NN model in Pytorch on the example of competition "[Mechanisms of Action (MoA) Prediction](https://www.kaggle.com/c/lish-moa)"

# %% [markdown]
# ## 5. Models selection <a class="anchor" id="5"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 5.1. Classifiers <a class="anchor" id="5.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [Automatic selection from 20 classifier models](https://www.kaggle.com/vbmokin/automatic-selection-from-20-classifier-models)**
#
# ### FE, tuning, *N_best_models* selection of the popular models by the given metrics (r2_score, relative error (basic on MAE) or RMSE (MSE)) and by them automatical creates *N_best_models* submission files
#
# The kernel realized on the example of competition "Titanic: Machine Learning from Disaster" -> LB = 0.83253 (Top 2%)
#
# **Automatic selection of binary classification models** works as follows (methodology worked out on the my kernel with 15 regression models - [Suspended substances prediction in river](https://www.kaggle.com/vbmokin/suspended-substances-prediction-in-river)) - a training dataset (on the given *path* to files) with a target column is divided into training and "test" (*test_train_split_part* = 0.2: train/test => 80/20% default). Models are built on the training set and are tested on a "test" set - which they give a match on given metrics (default metrics: *r2-score*, *relative error* and *rmse* but you can only select some from them). The user chooses which metric is the main one (*metric_main*) - it selects the *N_best_models* amount of most accurate models for this metric.
# Next, user may rebuild these the best of models on a full (100%) training dataset and apply to a true test file and generate *N_best_models* submission files - examples of this are given.
#
# This kernel work with such models:
# * Linear Regression, Logistic Regression
# * Naive Bayes
# * k-Nearest Neighbors algorithm
# * Perceptron
# * Support Vector Machines and Linear SVR
# * Stochastic Gradient Descent, GradientBoostingRegressor, RidgeCV, BaggingRegressor
# * Decision Tree Classifier, Random Forest, AdaBoostClassifier, XGBRegressor, LGBM, ExtraTreesRegressor
# * Gaussian Process Classification
# * MLPRegressor (Deep Learning)
# * VotingRegressor

# %% [markdown]
# Models selection for given metric for part (default=20%) of train data (other data uses for training of these models)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After that the kernel training the best of models for all (100%) train data and automatic creates submission files by these best models (it's guarantee LB = 0.83253 - Top 2%)

# %% [markdown]
# ## 5.2. Interactive Classifier <a class="anchor" id="5.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The [web service](http://www.ccom.ucsd.edu/~cdeotte/programs/classify.html)**
#
# **Thanks to @cdeotte**
#
# ### Interactive Amazing web service for different data type
#
# The service work with such models:
# * Logistic regression
# * k Nearest Neighbors
# * Naive Bayes
# * Decision Tree
# * Linear SVM
# * Neural Networks

# %% [markdown]
# This page demonstrates basic classifiers: k nearest neighbors, decision tree, and linear classifiers. The linear classifiers shown here are: naive Bayes, logistic regression, and support vector machine. Naive Bayes is part of a larger family of Bayes classifiers which include linear discriminant analysis (LDA) and quadratic discriminant analysis (QDA). Logistic regression is part of a larger family called generalized linear models. Linear classifiers base their decision on a linear combination of the features. Any linear model can be converted into a more flexible model such as quadratic by engineering new features from the old. For example, given x1 x2, create x3 = x1^2, x4 = x2^2, x5 = x1x2. Then you have a quadratic model. None-the-less, this is still a linear combination of features. It can be shown that naive Bayes, logistic regression, and support vector machines are all similar mathematically. They all make their decision based on a linear combination of features. For exampe, given x1 x2, they predict y is blue if and only if w0+w1x1+w2x2 > 0. They vary only in how they calculate the weights: w0,w1,w2.
#
# More advanced classifiers are created by combining multiple instances of these basic classifiers. Examples are neural networks, random forests, bagging, boosting, and stacking. Advanced classifiers create decision boundaries flexible enough to model any pattern. Click [here](http://www.ccom.ucsd.edu/~cdeotte/programs/neuralnetwork.html) to play with a neural network. Click [here](http://www.ccom.ucsd.edu/~cdeotte/programs/MNIST.html) to play with an application of neural networks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5.3. Regressors<a class="anchor" id="5.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [BOD prediction in river - 15 regression models](https://www.kaggle.com/vbmokin/bod-prediction-in-river-15-regression-models)**
#
# ### FE, tuning, *N_best_models* selection of the popular models by the given metrics (r2_score, relative error (basic on MAE) or RMSE (MSE)) and by them automatical creates *N_best_models* submission files
#
# The kernel work with such models:
# * Linear Regression
# * Support Vector Machines and Linear SVR
# * Stochastic Gradient Descent, GradientBoostingRegressor, RidgeCV, BaggingRegressor
# * Decision Tree Regression, Random Forest, XGBRegressor, LGBM, ExtraTreesRegressor
# * MLPRegressor (Deep Learning)
# * VotingRegressor

# %% [markdown]
# ## 5.4. Classifiers & Regressors<a class="anchor" id="5.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [A Guide to Decision Trees for Beginners](https://www.kaggle.com/vipulgandhi/a-guide-to-decision-trees-for-beginners)**
#
# Theory and Practice

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 2 [Hyperparameter tuning in XGBoost](https://www.kaggle.com/prashant111/hyperparameter-tuning-in-xgboost)**
#
# This kernel contains a very detailed description of the **XGBoost hyperparameters** and the algorithm for their optimization by **HYPEROPT** with code examples.

# %% [markdown]
# ## 5.5. Deep Learning<a class="anchor" id="5.5"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The Kaggle kernels collection [Data Science with DL & NLP: Advanced Techniques](https://www.kaggle.com/vbmokin/data-science-with-dl-nlp-advanced-techniques)**
#
# This is a collection of the best Kaggle kernels and other resources with Advanced Techniques of Data Science by Deep Learning (DL) including NLP

# %% [markdown]
# ## 5.6. User metric for models <a class="anchor" id="5.6"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [Physically Possible](https://www.kaggle.com/jazivxt/physically-possible)**
#
# Very interesting application of user metric (on basic **f1_score**) with additional processing in the code of LGB model training in the competition "[University of Liverpool - Ion Switching](https://www.kaggle.com/c/liverpool-ion-switching)"

# %% [markdown]
# **The kernel 2 [Ion Switching - LGB, MLP & Regr, ConfMatrices](https://www.kaggle.com/vbmokin/ion-switching-lgb-mlp-regr-confmatrices)**
#
# An example of using a user metric to train a MLP model (on basic **make_scorer** and **f1_score**) in the competition "[University of Liverpool - Ion Switching](https://www.kaggle.com/c/liverpool-ion-switching)"

# %% [markdown]
# ## 6. Time series analysis and prediction<a class="anchor" id="6"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 6.1. Statsmodels, ARIMA <a class="anchor" id="6.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel 1 [Everything you can do with a time series](https://www.kaggle.com/thebrownviking20/everything-you-can-do-with-a-time-series)**
#
# #### Statistics, ARIMA etc.:
# 1. Introduction to date and time
# 1.1 Importing time series data
# 1.2 Cleaning and preparing time series data
# 1.3 Visualizing the datasets
# 1.4 Timestamps and Periods
# 1.5 Using date_range
# 1.6 Using to_datetime
# 1.7 Shifting and lags
# 1.8 Resampling
#
# 2. Finance and Statistics
# 2.1 Percent change
# 2.2 Stock returns
# 2.3 Absolute change in successive rows
# 2.4 Comaring two or more time series
# 2.5 Window functions
# 2.6 OHLC charts
# 2.7 Candlestick charts
# 2.8 Autocorrelation and Partial Autocorrelation
#
# 3. Time series decomposition and Random Walks
# 3.1 Trends, Seasonality and Noise
# 3.2 White Noise
# 3.3 Random Walk
# 3.4 Stationarity
#
# 4. Modelling using statsmodels
# 4.1 AR models
# 4.2 MA models
# 4.3 ARMA models
# 4.4 ARIMA models
# 4.5 VAR models
# 4.6 State space methods
# 4.6.1 SARIMA models
# 4.6.2 Unobserved components
# 4.6.3 Dynamic Factor models

# %% [markdown]
# **The kernel 2 [Time Series For beginners with ARIMA](https://www.kaggle.com/freespirit08/time-series-for-beginners-with-arima)**
#
# #### Time series analysis and prediction:
# * Tests to check if a series is stationary or not
# * Data Transformation to achieve Stationarity,
# * Data description and cleaning, EDA of time series,
# * Autocorrelation function, plots
# * Rolling mean
# * Tutorial for ARIMA (includes AR, MA models), how to find value of P & Q for ARIMA
# * ADCF test (an augmented Dickey–Fuller test (ADF) tests the null hypothesis that a unit root is present in a time series sample)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 3 [Time Series Prediction Tutorial with EDA](https://www.kaggle.com/kanncaa1/time-series-prediction-tutorial-with-eda)**
#
# #### Time series analysis and prediction:
# * Data description and cleaning
# * EDA of time series
# * Autocorrelation function
# * Tutorial for ARIMA method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel 4 [Complete Guide on Time Series Analysis in Python](https://www.kaggle.com/prashant111/complete-guide-on-time-series-analysis-in-python)**
#
# #### Time series analysis and prediction:
# * Introduction to Time Series Analysis
# * Types of data
# * Time Series terminology
# * Visualize the Time Series
# * Patterns in a Time Series
# * Additive and Multiplicative Time Series
# * Decomposition of a Time Series
# * Stationary and Non-Stationary Time Series
# * How to make a time series stationary
# * How to test for stationarity (Augmented Dickey Fuller test (ADF Test), Kwiatkowski-Phillips-Schmidt-Shin – KPSS test (trend stationary), Philips Perron test (PP Test))
# * Difference between white noise and a stationary series
# * Detrend a Time Series
# * Deseasonalize a Time Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6.2. SARIMAX - Seasonal ARIMA <a class="anchor" id="6.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [CO2 Emission Forecast with Python (Seasonal ARIMA)](https://www.kaggle.com/berhag/co2-emission-forecast-with-python-seasonal-arima)**
#
# #### Seasonal time series analysis and prediction
# * Data description and cleaning
# * EDA of time series
# * Tutorial for SARIMAX (includes AR, MA, etc.)
# * Many good plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6.3. Test stationarity and transform the dataset to stationary<a class="anchor" id="6.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [CO2 Emission Forecast with Python (Seasonal ARIMA)](https://www.kaggle.com/berhag/co2-emission-forecast-with-python-seasonal-arima)**
#
# **Stationarity** is an assumption underlying many statistical procedures used in time series analysis, non-stationary data is often transformed to become stationary. The most common cause of violation of stationarity is a trend in the mean, which can be due to either the presence of a unit root or of a deterministic trend. If the nonstationarity is caused by the presence of unit root, stochastic shocks have permanent effects and the process is not mean-reverting. However, if it is caused by a deterministic trend, the process is called a trend stationary process, and stochastic shocks have only transitory effects after which the variable tends toward a deterministically evolving mean.
#
# A trend stationary process is not strictly stationary, but can easily be transformed into a stationary process by removing the underlying trend, which is solely a function of time. Similarly, processes with one or more unit roots can be made stationary through differencing. An important type of non-stationary process that does not include a trend-like behavior is a cyclostationary process, which is a stochastic process that varies cyclically with time.
#
# #### Test stationarity using Dickey-Fuller
# A formal way of testing stationarity of a dataset is using plotting the moving average or moving variance and see if the series mean and variance varies with time. This approach handled by the TestStationaryPlot() method. The second way to test stationarity is to use the statistical test (the Dickey-Fuller Test). The null hypothesis for the test is that the time series is non-stationary. The test results compare a Test Statistic and Critical Values (cutoff value) at different confidence levels. If the ‘Test Statistic’ is less than the ‘Critical Value’, we can reject the null hypothesis and say that the series is stationary. This technique handled by the TestStationaryAdfuller( ) method.
#
# #### Transform the dataset to stationary
# The most common techniques used to estimate or model trend and then remove it from the time series are
# * **Aggregation** – taking average for a time period like monthly/weekly average
# * **Smoothing** – taking rolling averages
# * **Polynomial Fitting** – fit a regression model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6.4. Time series with Facebook Prophet<a class="anchor" id="6.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The best tutorial for library Prophet is the materials from Facebook:**
# * https://research.fb.com/prophet-forecasting-at-scale/
# * https://facebook.github.io/prophet/docs/quick_start.html#python-api

# %% [markdown]
# **The kernel [Topic 9. Part 2. Time series with Facebook Prophet](https://www.kaggle.com/kashnitsky/topic-9-part-2-time-series-with-facebook-prophet)**
#
# #### Prophet Forecasting Model
# We will look at Prophet, a library for time series forecasting released by Facebook and open-sourced on February 23, 2017. We will also try it out in the problem of predicting the daily number of posts published on Medium.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The kernel [COVID-19 EDA and Forecasting](https://www.kaggle.com/n1sarg/covid-19-eda-and-forecasting)**
#
# #### Research for Competition "COVID19 Global Forecasting (Week 5)"
# Many interesting plots from Prophet forecasting

# %% [markdown]
# ## 7. Probability prediction with calibration<a class="anchor" id="7"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [CFEC - Probability calibration](https://www.kaggle.com/vbmokin/cfec-probability-calibration)**
#
# #### Probability prediction with calibration
#
# This kernel basic on the materials from https://scikit-learn.org/stable/modules/calibration.html
#
# Logistic Regression and Baive Bayes Model with calibration (Isotonic and Sigmoid) and without it

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **The Kaggle kernels collection [EDA for tabular data: Advanced Techniques](https://www.kaggle.com/vbmokin/eda-for-tabular-data-advanced-techniques)**
#
# This is a collection of the best Kaggle kernels with Advanced Techniques of Exploratory Data Analysis (EDA) for tabular data

# %% [markdown]
# ## 8. Universal toolkits<a class="anchor" id="8"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# ## 8.1. Sklearn<a class="anchor" id="8.1"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **Sklearn** (Scikit-learn) - Universal simple and efficient tools for predictive data analysis.
#
# Documentation: https://scikit-learn.org/stable/

# %% [markdown]
# **The kernel [sklearn: 50 best tips and tricks](https://www.kaggle.com/python10pm/sklearn-50-best-tips-and-tricks)**
#
# 50 very interesting and useful techniques based on the capabilities of the Sklearn library

# %% [markdown]
# ## 8.2. NumPy<a class="anchor" id="8.2"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **NumPy** - The fundamental package for scientific computing with Python.
#
# Documentation: https://numpy.org/doc/stable/

# %% [markdown]
# **The kernel [Learn Numpy the hard way: 70 exercises+solutions](https://www.kaggle.com/python10pm/learn-numpy-the-hard-way-70-exercises-solutions)**
#
# 70 very interesting and useful techniques based on the capabilities of the NumPy library

# %% [markdown]
# ## 8.3. Pandas<a class="anchor" id="8.3"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **Pandas** - is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool, built on top of the Python programming language.
#
# User guide: https://pandas.pydata.org/docs/user_guide/index.html

# %% [markdown]
# **The kernel [Pandas 100 tricks](https://www.kaggle.com/python10pm/pandas-100-tricks)**
#
# 100 very interesting and useful tricks and techniques based on the capabilities of the Pandas library

# %% [markdown]
# **The kernel [Pandas 75 exercises with solutions](https://www.kaggle.com/python10pm/pandas-75-exercises-with-solutions)**
#
# 75 very interesting and useful techniques and exercises based on the capabilities of the Pandas library

# %% [markdown]
# ## 8.4. Auto ML<a class="anchor" id="8.4"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **Cloud AutoML** (Google Cloud)
#
# Documentation: https://cloud.google.com/automl
#
# Train high-quality custom machine learning models with minimal effort and machine learning expertise.
#
# Create your own custom machine learning models with an easy-to-use graphical interface.
#
# * AI Platform (Unified) with AutoML (Preview)
# * AutoML Vision
# * AutoML Video Intelligence (beta)
# * AutoML Natural Language
# * AutoML Translation
# * AutoML Tables (beta)

# %% [markdown]
# **The kernel [AutoML Getting Started Notebook](https://www.kaggle.com/yufengg/automl-getting-started-notebook)**
#
# Step-by-step instructions with examples of how to apply AutoML for NLP tasks.

# %% [markdown]
# ## 8.5. PyCaret<a class="anchor" id="8.5"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **CARET** - short for **C**lassification **A**nd **RE**gression **T**raining)
# * Caret - for R
# * PyCaret - for Python

# %% [markdown]
# **The kernel [PyCaret Introduction (Classification & Regression)](https://www.kaggle.com/frtgnn/pycaret-introduction-classification-regression)**
#
# Pycaret website and documentation: https://pycaret.org
#
# PyCaret is an open source, low-code machine learning library in Python that allows you to go from preparing your data to deploying your model within seconds in your choice of notebook environment.
#
# PyCaret being a low-code library makes you more productive. With less time spent coding, you and your team can now focus on business problems.
#
# PyCaret is simple and easy to use machine learning library that will help you to perform end-to-end ML experiments with less lines of code.
#
# PyCaret is a business ready solution. It allows you to do prototyping quickly and efficiently from your choice of notebook environment.

# %% [markdown]
# ## 9. DS Tutorials<a class="anchor" id="9"></a>
#
# [Back to Table of Contents](#0.1)

# %% [markdown]
# **The kernel [The Data Scientist’s Toolbox Tutorial - 1](https://www.kaggle.com/jackyourdata/the-data-scientist-s-toolbox-tutorial-1)**
#
# You may be interested have a look at 10 Steps to Become a Data Scientist:
# * You are in the first step
# * Python Packages
# * Mathematics and Linear Algebra
# * Programming & Analysis Tools
# * Big Data
# * Data visualization
# * Data Cleaning
# * How to solve a Problem?
# * Machine Learning
# * Deep Learning

# %% [markdown]
# **The post ["Techniques to improve your leaderboard position"](https://www.kaggle.com/c/tabular-playground-series-jan-2021/discussion/213090) from Grandmaster @gpreda**
#
# Lots of helpful tips and links to examples of their application regarding:
# * data preprocessing,
# * FE,
# * model tuning,
# * merge solutions etc.

# %% [markdown]
# I hope you find this kernel useful and enjoyable.

# %% [markdown]
# Your comments and feedback are most welcome.

# %% [markdown]
# **I will continue this list first of all the decisions of the winners of the competitions and the most voted kernels of Kaggle Kernels Grandmasters, Masters or Experts. I ask those who know such decisions, write about them in the comments**

# %% [markdown]
# [](http://)[Go to Top](#0)
